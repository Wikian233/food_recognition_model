# %%
pip install wandb==0.12.11

# %%
import wandb
from wandb.keras import WandbCallback
wandb.init(project="yolov5_lite", entity="ultralytics")
config = wandb.config
config.epochs = 100
config.batch_size = 16
config.learning_rate = 0.001
config.img_size = 416
config.train = "/content/drive/MyDrive/Colab Notebooks/Train"

# %% [markdown]
# #### labels_shower.py

# %% [markdown]
# #### Model Training YOLOv5-Lite-s

# %%
# !python train.py --data 'data/UNIMIB2016.yaml' --cfg 'models/v5Lite-s.yaml' --weights 'pretrained/v5lite-s.pt' --epoch 100 --batch-size 16 --adam
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 2023-4-7 torch 1.12.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5921.5625MB)
#
# Namespace(weights='pretrained/v5lite-s.pt', cfg='models/v5Lite-s.yaml', data='data/UNIMIB2016.yaml', hyp='data/hyp.scratch.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=True, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='exp', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', world_size=1, global_rank=-1, save_dir='runs/train/exp4', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --source /home/weijian/Deep_Learning_ws/food_recognition_model/datasets/UNIMIB2016/images/20151211_114703.jpg --weights ./runs/train/exp4/weights/best.pt
# Out:
# Namespace(weights=['./runs/train/exp4/weights/best.pt'], source='/home/weijian/Deep_Learning_ws/food_recognition_model/datasets/UNIMIB2016/images/20151211_114703.jpg', img_size=640, conf_thres=0.45, iou_thres=0.5, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False)
# YOLOv5 🚀 2023-4-7 torch 1.12.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5921.5625MB)
#
# Fusing layers...
# /home/weijian/anaconda3/envs/PyTorch/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809662/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 230 layers, 1629837 parameters, 0 gradients, 3.9 GFLOPS
# ...

# %%
# update pip
# !pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.0 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...

# %%
# !pip install  onnx
# !pip install  onnxsim

# %%
# !python export.py --weights 'runs/train/exp4/weights/best.pt' --batch-size 1 --img-size 320
# Out:
# Namespace(weights='runs/train/exp4/weights/best.pt', img_size=[320, 320], concat=True, batch_size=1, dynamic=False, grid=False, device='cpu')
# YOLOv5 🚀 2023-4-7 torch 1.12.1 CPU
#
# Fusing layers...
# /home/weijian/anaconda3/envs/PyTorch/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809662/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 230 layers, 1629837 parameters, 0 gradients, 3.9 GFLOPS
# Detect(
#   (m): ModuleList(
#     (0): Conv2d(64, 231, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(128, 231, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(256, 231, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
#
# Starting ONNX export with onnx 1.13.1...
# ...

# %%
# !python -m onnxsim runs/train/exp4/weights/best.onnx runs/train/exp4/weights/best-sim.onnx
# Out:
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 13             │ 0                │
# │ Concat     │ 25             │ 25               │
# │ Constant   │ 112            │ 0                │
# │ Conv       │ 82             │ 82               │
# │ Div        │ 13             │ 0                │
# │ Gather     │ 13             │ 0                │
# │ Identity   │ 3              │ 0                │
# │ MaxPool    │ 1              │ 1                │
# │ Mul        │ 50             │ 24               │
# │ Relu       │ 36             │ 36               │
# │ Reshape    │ 38             │ 38               │
# │ Resize     │ 2              │ 2                │
# │ Shape      │ 13             │ 0                │
# │ Sigmoid    │ 27             │ 27               │
# ...
